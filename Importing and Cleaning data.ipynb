# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'

# %%
# import the necessary libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(url,sep='|')

# %%
#to load specific columns
df[['age','gender']]
# Out:
#      age gender
# 0     24      M
# 1     53      F
# 2     23      M
# 3     24      M
# 4     33      F
# ..   ...    ...
# 938   26      F
# 939   32      M
# 940   20      M
# 941   48      F
# 942   22      M
#
# [943 rows x 2 columns]

# %%
df.nrows
# Out:
# 2

# %%
#to list rows
df=pd.read_csv(url,sep='|')
df
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
#to set index to column user_id
df.set_index('user_id')
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
# to list first 5 rows
df.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
#to list last 5 rows
df.tail()
# Out:
#    user_id  age gender     occupation  zip_code
# 3        4   24      M     technician     43537
# 4        5   33      F          other     15213
# 5        6   42      M      executive     98101
# 6        7   57      M  administrator     91344
# 7        8   36      M  administrator      5201

# %%
# to check information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     943 non-null    int64
#  1   age         943 non-null    int64
#  2   gender      943 non-null    object
#  3   occupation  943 non-null    object
#  4   zip_code    943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB

# %%
# to check column data types
df.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
# to describe the data(numeric)
df.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
# to describe the data with including alphabic
df.describe(include='all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %%
# to check observation and features
df.shape
# Out:
# (943, 5)

# %%
df.size
# Out:
# 4715

# %%
#to list columns
df.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
# to check unique values
df['gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
# to check unique value count
df['gender'].nunique()
# Out:
# 2

# %%
# to count total number of values
df.value_counts()
# Out:
# user_id  age  gender  occupation  zip_code
# 1        24   M       technician  85711       1
# 634      39   M       engineer    T8H1N       1
# 622      25   M       programmer  14850       1
# 623      50   F       educator    60187       1
# 624      19   M       student     30067       1
#                                              ..
# 319      38   M       programmer  22030       1
# 320      19   M       student     24060       1
# 321      49   F       educator    55413       1
# 322      20   M       student     50613       1
# 943      22   M       student     77841       1
# Length: 943, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# M    670
# F    273
# Name: gender, dtype: int64

# %%
df['occupation'].value_counts()
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: occupation, dtype: int64

# %%
df['occupation'].value_counts(normalize=True)*100
# Out:
# student          20.784730
# other            11.134677
# educator         10.074231
# administrator     8.377519
# engineer          7.104984
# programmer        6.998940
# librarian         5.408271
# writer            4.772004
# executive         3.393425
# scientist         3.287381
# artist            2.969247
# technician        2.863203
# marketing         2.757158
# entertainment     1.908802
# healthcare        1.696713
# retired           1.484624
# lawyer            1.272534
# salesman          1.272534
# none              0.954401
# homemaker         0.742312
# doctor            0.742312
# Name: occupation, dtype: float64

# %%
df['gender'].value_counts(normalize=True)
# Out:
# M    0.710498
# F    0.289502
# Name: gender, dtype: float64

# %%
#bar chart
df['occupation'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#cross table
pd.crosstab(df['gender'],df['occupation'])
# Out:
# occupation  administrator  artist  doctor  educator  engineer  entertainment  \
# gender
# F                      36      13       0        26         2              2
# M                      43      15       7        69        65             16
#
# occupation  executive  healthcare  homemaker  lawyer  ...  marketing  none  \
# gender                                                ...
# F                   3          11          6       2  ...         10     4
# M                  29           5          1      10  ...         16     5
#
# occupation  other  programmer  retired  salesman  scientist  student  \
# gender
# F              36           6        1         3          3       60
# M              69          60       13         9         28      136
#
# occupation  technician  writer
# gender
# F                    1      19
# M                   26      26
#
# [2 rows x 21 columns]

# %%
#cross table
pd.crosstab(df['gender'],df['occupation'],margins=True)
# Out:
# occupation  administrator  artist  doctor  educator  engineer  entertainment  \
# gender
# F                      36      13       0        26         2              2
# M                      43      15       7        69        65             16
# All                    79      28       7        95        67             18
#
# occupation  executive  healthcare  homemaker  lawyer  ...  none  other  \
# gender                                                ...
# F                   3          11          6       2  ...     4     36
# M                  29           5          1      10  ...     5     69
# All                32          16          7      12  ...     9    105
#
# occupation  programmer  retired  salesman  scientist  student  technician  \
# gender
# F                    6        1         3          3       60           1
# M                   60       13         9         28      136          26
# ...

# %%
#cross table in percentage
pd.crosstab(df['age'],df['gender'],normalize='index').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# convert one data type to another
df.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
df['age']=df['age'].astype('object')

# %%
df.dtypes
# Out:
# user_id        int64
# age           object
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
df['age']=df['age'].astype('int64')

# %%
df.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
# correlation (implements only on numeric)
df.corr()
# Out:
#           user_id       age
# user_id  1.000000  0.003181
# age      0.003181  1.000000

# %%
sns.heatmap(df.corr()) #(we are using seaborn library)
# Out:
# <AxesSubplot:>

# %%
#pps(predictive power score)
import ppscore as pps
pps.matrix(df)
# Out:
# C:\Users\acer01\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(("The least populated class in y has only %d"
# C:\Users\acer01\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(("The least populated class in y has only %d"
# C:\Users\acer01\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(("The least populated class in y has only %d"
# ...

# %%
df.boxplot(column='age',by='gender')
# Out:
# <AxesSubplot:title={'center':'age'}, xlabel='gender'>

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(df)
#pandas_profiling.ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-11-01 17:02:05.107775&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # Data cleaning

# %%
#check dublicates
df.duplicated().sum()
# Out:
# 0

# %%
#to delete duplicate
df.drop_duplicates()
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
#missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     943 non-null    int64
#  1   age         943 non-null    int64
#  2   gender      943 non-null    object
#  3   occupation  943 non-null    object
#  4   zip_code    943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB

# %%
#to check missing values
df.isnull().sum()
# Out:
# user_id       0
# age           0
# gender        0
# occupation    0
# zip_code      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# user_id       0
# age           0
# gender        0
# occupation    0
# zip_code      0
# dtype: int64

# %%
df1=pd.read_csv('train.csv')
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df1[df1['Gender'].isna()]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 23   LP001050    NaN     Yes          2  Not Graduate            No
# 126  LP001448    NaN     Yes         3+      Graduate            No
# 171  LP001585    NaN     Yes         3+      Graduate            No
# 188  LP001644    NaN     Yes          0      Graduate           Yes
# 314  LP002024    NaN     Yes          0      Graduate            No
# 334  LP002103    NaN     Yes          1      Graduate           Yes
# 460  LP002478    NaN     Yes          0      Graduate           Yes
# 467  LP002501    NaN     Yes          0      Graduate            No
# 477  LP002530    NaN     Yes          2      Graduate            No
# 507  LP002625    NaN      No          0      Graduate            No
# 576  LP002872    NaN     Yes          0      Graduate            No
# 588  LP002925    NaN      No          0      Graduate            No
# 592  LP002933    NaN      No         3+      Graduate           Yes
#
# ...

# %%
df1.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df1[df1['Married'].isnull()]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 104  LP001357    Male     NaN        NaN  Graduate            No
# 228  LP001760    Male     NaN        NaN  Graduate            No
# 435  LP002393  Female     NaN        NaN  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 104             3816              754.0       160.0             360.0
# 228             4758                0.0       158.0             480.0
# 435            10047                0.0         NaN             240.0
#
#      Credit_History Property_Area Loan_Status
# 104             1.0         Urban           Y
# 228             1.0     Semiurban           Y
# 435             1.0     Semiurban           Y

# %%
d=df1.dropna()
d
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            480 non-null    object
#  1   Gender             480 non-null    object
#  2   Married            480 non-null    object
#  3   Dependents         480 non-null    object
#  4   Education          480 non-null    object
#  5   Self_Employed      480 non-null    object
#  6   ApplicantIncome    480 non-null    int64
#  7   CoapplicantIncome  480 non-null    float64
#  8   LoanAmount         480 non-null    float64
#  9   Loan_Amount_Term   480 non-null    float64
#  10  Credit_History     480 non-null    float64
#  11  Property_Area      480 non-null    object
#  12  Loan_Status        480 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 52.5+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
c=df1.dropna(subset=['Gender'])

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 601 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            601 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            598 non-null    object
#  3   Dependents         586 non-null    object
#  4   Education          601 non-null    object
#  5   Self_Employed      569 non-null    object
#  6   ApplicantIncome    601 non-null    int64
#  7   CoapplicantIncome  601 non-null    float64
#  8   LoanAmount         579 non-null    float64
#  9   Loan_Amount_Term   587 non-null    float64
#  10  Credit_History     552 non-null    float64
#  11  Property_Area      601 non-null    object
#  12  Loan_Status        601 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 65.7+ KB

# %%
# to find null values in gender column
df1['Gender'].isnull().sum()
# Out:
# 13

# %%
# to count values
df1['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
# find out max item
df1['Gender'].mode()
# Out:
# 0    Male
# dtype: object

# %%
# adding male to null rows
df1['Gender']=df1['Gender'].fillna(df1['Gender'].mode()[0])

# %%
df1['Gender'].value_counts()
# Out:
# Male      502
# Female    112
# Name: Gender, dtype: int64

# %%
df1['Gender'].isnull().sum()
# Out:
# 0

# %%
df1['Married'].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
df1['Married'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df1['Married']=df1['Married'].fillna('maybe')

# %%
#new file has been save in jupyter folder
df1.to_csv('train_updated.csv')
