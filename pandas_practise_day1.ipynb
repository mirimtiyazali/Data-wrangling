# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')

# %%
pip install openpyxl
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\acer01\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import openpyxl

# %%
df
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 0  2019-01-06     East     Jones   Pencil     95       1.99   189.05
# 1  2019-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2019-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2019-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2019-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2019-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2019-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 7  2019-05-05  Central   Jardine   Pencil     90       4.99   449.10
# 8  2019-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2019-06-08     East     Jones   Binder     60       8.99   539.40
# 10 2019-06-25  Central    Morgan   Pencil     90       4.99   449.10
# 11 2019-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2019-07-29     East    Parent   Binder     81      19.99  1619.19
# ...

# %%
df1=pd.read_csv('train.csv')

# %%
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (43, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OrderDate  43 non-null     datetime64[ns]
#  1   Region     43 non-null     object
#  2   Rep        43 non-null     object
#  3   Item       43 non-null     object
#  4   Units      43 non-null     int64
#  5   Unit Cost  43 non-null     float64
#  6   Total      43 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 2.5+ KB

# %%
pd.set_option('display.max_columns',7)# to display total number of columns

# %%
df.columns
# Out:
# Index(['OrderDate', 'Region', 'Rep', 'Item', 'Units', 'Unit Cost', 'Total'], dtype='object')

# %%
df.head()# to check first 5 rows
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
df.tail()# to check last 5 rows
# Out:
#     OrderDate   Region       Rep    Item  Units  Unit Cost    Total
# 38 2020-10-14     West  Thompson  Binder     57      19.99  1139.43
# 39 2020-10-31  Central   Andrews  Pencil     14       1.29    18.06
# 40 2020-11-17  Central   Jardine  Binder     11       4.99    54.89
# 41 2020-12-04  Central   Jardine  Binder     94      19.99  1879.06
# 42 2020-12-21  Central   Andrews  Binder     28       4.99   139.72

# %%
person={
    'first':'corey',
    'last':'schafer',
    'email':'coreymschafer@gmail.com'
}

# %%
people={
    'first':['corey'],
    'last':['schafer'],
    'email':['coreymschafer@gmail.com']
}

# %%
peoples={
     'first':['corey','jane','john'],
     'last':['schafer','doe','doe'],
     'email':['coreymschafer@gmail.com','janedoe@email.com','johndeo@email.com']  
}

# %%
people['email']
# Out:
# ['coreymschafer@gmail.com']

# %%
df=pd.DataFrame(peoples)

# %%
df
# Out:
#    first     last                    email
# 0  corey  schafer  coreymschafer@gmail.com
# 1   jane      doe        janedoe@email.com
# 2   john      doe        johndeo@email.com

# %%
df['email']
# Out:
# 0    coreymschafer@gmail.com
# 1          janedoe@email.com
# 2          johndeo@email.com
# Name: email, dtype: object

# %%
df['first']
# Out:
# 0    corey
# 1     jane
# 2     john
# Name: first, dtype: object

# %%
type(df['first'])
# Out:
# pandas.core.series.Series

# %%
df.email
# Out:
# 0    coreymschafer@gmail.com
# 1          janedoe@email.com
# 2          johndeo@email.com
# Name: email, dtype: object

# %%
df[['first','email']]
# Out:
#    first                    email
# 0  corey  coreymschafer@gmail.com
# 1   jane        janedoe@email.com
# 2   john        johndeo@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
#iloc to extract data by index position
df.iloc[0]
# Out:
# first                      corey
# last                     schafer
# email    coreymschafer@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[1:]
# Out:
#   first last              email
# 1  jane  doe  janedoe@email.com
# 2  john  doe  johndeo@email.com

# %%
#loc to get result by column 
df.loc[0]
# Out:
# first                      corey
# last                     schafer
# email    coreymschafer@gmail.com
# Name: 0, dtype: object

# %%
df.loc[[1,2]]
# Out:
#   first last              email
# 1  jane  doe  janedoe@email.com
# 2  john  doe  johndeo@email.com

# %%
df.loc[[1,2],['email','last']]
# Out:
#                email last
# 1  janedoe@email.com  doe
# 2  johndeo@email.com  doe

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 0  2019-01-06     East     Jones   Pencil     95       1.99   189.05
# 1  2019-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2019-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2019-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2019-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2019-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2019-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 7  2019-05-05  Central   Jardine   Pencil     90       4.99   449.10
# 8  2019-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2019-06-08     East     Jones   Binder     60       8.99   539.40
# 10 2019-06-25  Central    Morgan   Pencil     90       4.99   449.10
# 11 2019-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2019-07-29     East    Parent   Binder     81      19.99  1619.19
# ...

# %%
df.shape
# Out:
# (43, 7)

# %%
df.columns
# Out:
# Index(['OrderDate', 'Region', 'Rep', 'Item', 'Units', 'Unit Cost', 'Total'], dtype='object')

# %%
df['Item'].head()
# Out:
# 0    Pencil
# 1    Binder
# 2    Pencil
# 3       Pen
# 4    Pencil
# Name: Item, dtype: object

# %%
df.count()
# Out:
# OrderDate    43
# Region       43
# Rep          43
# Item         43
# Units        43
# Unit Cost    43
# Total        43
# dtype: int64

# %%
df.iloc[[2,5]]
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 5 2019-04-01     East    Jones  Binder     60       4.99  299.40

# %%
df.loc[0]
# Out:
# OrderDate    2019-01-06 00:00:00
# Region                      East
# Rep                        Jones
# Item                      Pencil
# Units                         95
# Unit Cost                   1.99
# Total                     189.05
# Name: 0, dtype: object

# %%
df.loc[0,'Rep']
# Out:
# 'Jones'

# %%
df.loc[0:5] #with slicing
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44
# 5 2019-04-01     East    Jones  Binder     60       4.99  299.40

# %%
df.loc[0:10,'Rep':'Total']
# Out:
#          Rep    Item  Units  Unit Cost   Total
# 0      Jones  Pencil     95       1.99  189.05
# 1     Kivell  Binder     50      19.99  999.50
# 2    Jardine  Pencil     36       4.99  179.64
# 3       Gill     Pen     27      19.99  539.73
# 4    Sorvino  Pencil     56       2.99  167.44
# 5      Jones  Binder     60       4.99  299.40
# 6    Andrews  Pencil     75       1.99  149.25
# 7    Jardine  Pencil     90       4.99  449.10
# 8   Thompson  Pencil     32       1.99   63.68
# 9      Jones  Binder     60       8.99  539.40
# 10    Morgan  Pencil     90       4.99  449.10

# %%
df.iloc[0:10,2:6]
# Out:
#         Rep    Item  Units  Unit Cost
# 0     Jones  Pencil     95       1.99
# 1    Kivell  Binder     50      19.99
# 2   Jardine  Pencil     36       4.99
# 3      Gill     Pen     27      19.99
# 4   Sorvino  Pencil     56       2.99
# 5     Jones  Binder     60       4.99
# 6   Andrews  Pencil     75       1.99
# 7   Jardine  Pencil     90       4.99
# 8  Thompson  Pencil     32       1.99
# 9     Jones  Binder     60       8.99

# %%
df.set_index('OrderDate').head() # to set index if not work then --df.set_index('email',inplace=True)
# Out:
#              Region      Rep    Item  Units  Unit Cost   Total
# OrderDate
# 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 2019-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 2019-02-26  Central     Gill     Pen     27      19.99  539.73
# 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
df.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
df.set_index('Region').head()
# Out:
#          OrderDate      Rep    Item  Units  Unit Cost   Total
# Region
# East    2019-01-06    Jones  Pencil     95       1.99  189.05
# Central 2019-01-23   Kivell  Binder     50      19.99  999.50
# Central 2019-02-09  Jardine  Pencil     36       4.99  179.64
# Central 2019-02-26     Gill     Pen     27      19.99  539.73
# West    2019-03-15  Sorvino  Pencil     56       2.99  167.44

# %%
df.index
# Out:
# RangeIndex(start=0, stop=43, step=1)

# %%
df.set_index('Rep').head()
# Out:
#          OrderDate   Region    Item  Units  Unit Cost   Total
# Rep
# Jones   2019-01-06     East  Pencil     95       1.99  189.05
# Kivell  2019-01-23  Central  Binder     50      19.99  999.50
# Jardine 2019-02-09  Central  Pencil     36       4.99  179.64
# Gill    2019-02-26  Central     Pen     27      19.99  539.73
# Sorvino 2019-03-15     West  Pencil     56       2.99  167.44

# %%
df.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
df.index
# Out:
# RangeIndex(start=0, stop=43, step=1)

# %%
df.sort_index().head()#by default ascending order
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
df.sort_index(ascending=False).head()
# Out:
#     OrderDate   Region       Rep    Item  Units  Unit Cost    Total
# 42 2020-12-21  Central   Andrews  Binder     28       4.99   139.72
# 41 2020-12-04  Central   Jardine  Binder     94      19.99  1879.06
# 40 2020-11-17  Central   Jardine  Binder     11       4.99    54.89
# 39 2020-10-31  Central   Andrews  Pencil     14       1.29    18.06
# 38 2020-10-14     West  Thompson  Binder     57      19.99  1139.43

# %%
(df['Item']=='Pencil').head()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: Item, dtype: bool

# %%
filt = (df['Item'] == 'Pencil')#to filter the data to get exact result

# %%
df[filt].head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44
# 6 2019-04-18  Central  Andrews  Pencil     75       1.99  149.25
# 7 2019-05-05  Central  Jardine  Pencil     90       4.99  449.10

# %%
df.loc[filt].head()# by using loc
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44
# 6 2019-04-18  Central  Andrews  Pencil     75       1.99  149.25
# 7 2019-05-05  Central  Jardine  Pencil     90       4.99  449.10

# %%
df.loc[filt,'Rep'].head()
# Out:
# 0      Jones
# 2    Jardine
# 4    Sorvino
# 6    Andrews
# 7    Jardine
# Name: Rep, dtype: object

# %%
filt=(df['Region'] == 'East') & (df['Item']== 'Pencil')#using and operator

# %%
df[filt]
# Out:
#     OrderDate Region    Rep    Item  Units  Unit Cost   Total
# 0  2019-01-06   East  Jones  Pencil     95       1.99  189.05
# 13 2019-08-15   East  Jones  Pencil     35       4.99  174.65

# %%
filt=(df['Region'] == 'East') | (df['Item']== 'Pencil')# using or operator

# %%
df[filt].head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44
# 5 2019-04-01     East    Jones  Binder     60       4.99  299.40
# 6 2019-04-18  Central  Andrews  Pencil     75       1.99  149.25

# %%
high_units=(df['Units']>80)
df[high_units]
# Out:
#     OrderDate   Region      Rep     Item  Units  Unit Cost    Total
# 0  2019-01-06     East    Jones   Pencil     95       1.99   189.05
# 7  2019-05-05  Central  Jardine   Pencil     90       4.99   449.10
# 10 2019-06-25  Central   Morgan   Pencil     90       4.99   449.10
# 12 2019-07-29     East   Parent   Binder     81      19.99  1619.19
# 19 2019-11-25  Central   Kivell  Pen Set     96       4.99   479.04
# 23 2020-02-01  Central    Smith   Binder     87      15.00  1305.00
# 28 2020-04-27     East   Howard      Pen     96       4.99   479.04
# 41 2020-12-04  Central  Jardine   Binder     94      19.99  1879.06

# %%
high_units=(df['Units']>80)& (df['Region']=='East')
df.loc[high_units,['Region','Units']]#loc must when filter with column name
# Out:
#    Region  Units
# 0    East     95
# 12   East     81
# 28   East     96

# %%
customer=['Jones','Smith']
filt=df['Rep'].isin(customer)

# %%
df[filt]
# Out:
#     OrderDate   Region    Rep     Item  Units  Unit Cost    Total
# 0  2019-01-06     East  Jones   Pencil     95       1.99   189.05
# 5  2019-04-01     East  Jones   Binder     60       4.99   299.40
# 9  2019-06-08     East  Jones   Binder     60       8.99   539.40
# 13 2019-08-15     East  Jones   Pencil     35       4.99   174.65
# 14 2019-09-01  Central  Smith     Desk      2     125.00   250.00
# 15 2019-09-18     East  Jones  Pen Set     16      15.99   255.84
# 17 2019-10-22     East  Jones      Pen     64       8.99   575.36
# 20 2019-12-12  Central  Smith   Pencil     67       1.29    86.43
# 23 2020-02-01  Central  Smith   Binder     87      15.00  1305.00
# 24 2020-02-18     East  Jones   Binder      4       4.99    19.96
# 32 2020-07-04     East  Jones  Pen Set     62       4.99   309.38

# %%
filt=df['subject'].str.contains('python',na=False)
# to extract python from row where data is in html/css;java;python,dbms
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'subject'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[filt].nunique()

# %% [markdown]
# # columns modifying

# %%
df.columns# to check columns

# %%
df.columns=['OrderDate','Region','Rep','Items','Units','Unit_Cost','Total']# to chnage columns

# %%
df.columns

# %%
df.head()

# %%
df.columns=[x.upper() for x in df.columns]# to upper the columns name

# %%
df.columns

# %%
df.columns=[x.lower() for x in df.columns]
df.columns
# to lower the columns name

# %%
df.columns=df.columns.str.replace('_','')# to remove space between columns
df.columns

# %%
df.rename(columns={'orderdate':'order_date','unitcost':'unit_cost'},inplace=True)
# to change specfic column name(inplace must)

# %%
df.columns

# %% [markdown]
# # row modfying

# %%
df.loc[[2,4]]# to check specific row

# %%
df.loc[2]=['2019-02-09','Central','Jardine','Pen',63,5.99,179.64]#to modifi row wise data

# %%
df.loc[[2,4]]

# %%
df.loc[2]=['2019-02-09','Central','James','pencil'] #if not equal to columns then error

# %%
df.loc[[2,4]]# to check specific row

# %%
df.loc[2,['region','items']]=['West','Pencil']#to change specfic row with specific column

# %%
df.loc[[2,4]]

# %%
df.loc[2,'region']=['Central']#to change single row

# %%
df.loc[[2,4]]

# %%
df['region'].str.lower().head()#to lower the data column wise but the chages wont save

# %%
df.head()

# %%
df['region']=df['region'].str.lower().head()#changes are done
df.head()

# %%
4 methods for modification
apply 
map
applymap
replace

# %%
df.head()

# %% [markdown]
# # add/remove column

# %%
peoples

# %%
df1.head()

# %%
df1.dtypes

# %%
df1['status']=df1['Gender'] +' '+ df1['Married']#added two columns and created new column

# %%
df1.head()

# %%
df1.drop(columns=['status'])#drop column single .multiple('status','gender')

# %%
df1.head()#status column not removed untill inplace=True not added

# %%
df1.drop(columns=['status'],inplace=True)

# %%
df1.head()

# %%
df1['status']=df1['Gender'] +' '+ df1['Married']#added columns to function split function

# %%
df1['status'].str.split(' ')

# %%
df1['status'].str.split(' ',expand=True)

# %%
df1[['Gender','Married']]=df1['status'].str.split(' ',expand=True)

# %%
df1.head()

# %% [markdown]
# # add/remove rows

# %%
df1.append({'Gender':'other'},ignore_index=True)# to add single row

# %%
#to add multiple rows check peoples dataframe on top
df2=pd.DataFrame(peoples)
df2

# %%
df.append(df2,ignore_index=True,sort=False) #to add multiple row from one data frame to another

# %%
df.columns

# %%
df.drop(index=41) #to add row base on index position

# %%
df.drop(index=df[df['Units']==7].index)#to romove rows base on condition(7)
or
#filt=df['Units']==7
#df.drop(index=df[filt].index)
